# %%
import numpy as np
from pyecharts import Page,Line,Bar,Overlap
#dt_AK = np.dtype(('S10,f8', 10))  

#dt = np.dtype([('name', np.str, 16), ('grades', np.float64, (2,2))]) 

dt=np.dtype([('name','S6')])

attr=np.empty((20),dtype=dt)
attrA=np.empty((40),dtype=dt)
attrK=np.empty((40),dtype=dt)

def custom_formatter(params):

    b= params.value[2]+10.0
    return b
for i in range(0,20):
    attr[i]=str(i)+"m/s"
for i in range(0,40):
    attrA[i]="A="+str(round((i*0.05+5),2))
    attrK[i]="K="+str((round((i*0.05+1.5),2)))

v1 = np.random.rand(40)
print(v1)
Line_name1 ="weibull_distribution_accumulation"
Line_name1 = Line("when change A")
Line_name1.add("weibull_distribution when A=",attrA, v1,is_xaxislabel_align=True,is_xaxis_boundarygap=False,line_curve =0.2,tooltip_formatter=custom_formatter)

page = Page()  
page.add(Line_name1)
page
# Out:
# [0.98995913 0.40729645 0.88680482 0.63283945 0.03405677 0.37490429
#  0.16148395 0.15898059 0.5702126  0.55977376 0.05828224 0.33035447
#  0.68572699 0.34996931 0.88686677 0.34621988 0.57888838 0.10951192
#  0.67776772 0.01259925 0.06962522 0.58667383 0.60791373 0.22281644
#  0.92382809 0.11716131 0.52676571 0.61816186 0.91239835 0.04375882
#  0.64698369 0.6475905  0.14623409 0.7047223  0.60561638 0.60641367
#  0.15328106 0.2297824  0.67847332 0.6826954 ]
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ffb2ae64c1804791a0330c1ab3c38ba0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ffb2ae64c1804791a0330c1ab3c38ba0 = echarts.init(document.getElementById('ffb2ae64c1804791a0330c1ab3c38ba0'), 'light', {renderer: 'canvas'});
# function custom_formatter(params) {
#     var b;
#     b = (params.value[2] + 10.0);
#     return b;
# }
#
# var option_ffb2ae64c1804791a0330c1ab3c38ba0 = {
#     "title": [
#         {
#             "text": "when change A",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6617385,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": custom_formatter,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "weibull_distribution when A=",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "A=5.0",
#                     0.9899591336965718
#                 ],
#                 [
#                     "A=5.05",
#                     0.4072964497905528
#                 ],
#                 [
#                     "A=5.1",
#                     0.8868048150067622
#                 ],
#                 [
#                     "A=5.15",
#                     0.6328394541780489
#                 ],
#                 [
#                     "A=5.2",
#                     0.03405676713653227
#                 ],
#                 [
#                     "A=5.25",
#                     0.3749042894622876
#                 ],
#                 [
#                     "A=5.3",
#                     0.1614839458860844
#                 ],
#                 [
#                     "A=5.35",
#                     0.15898059475855186
#                 ],
#                 [
#                     "A=5.4",
#                     0.5702126039884555
#                 ],
#                 [
#                     "A=5.45",
#                     0.559773758817075
#                 ],
#                 [
#                     "A=5.5",
#                     0.05828223867438809
#                 ],
#                 [
#                     "A=5.55",
#                     0.33035447311077937
#                 ],
#                 [
#                     "A=5.6",
#                     0.6857269862678854
#                 ],
#                 [
#                     "A=5.65",
#                     0.3499693136073191
#                 ],
#                 [
#                     "A=5.7",
#                     0.886866770367738
#                 ],
#                 [
#                     "A=5.75",
#                     0.34621988034047857
#                 ],
#                 [
#                     "A=5.8",
#                     0.5788883790789221
#                 ],
#                 [
#                     "A=5.85",
#                     0.10951191724728682
#                 ],
#                 [
#                     "A=5.9",
#                     0.677767717107732
#                 ],
#                 [
#                     "A=5.95",
#                     0.012599250407503204
#                 ],
#                 [
#                     "A=6.0",
#                     0.06962522267401805
#                 ],
#                 [
#                     "A=6.05",
#                     0.5866738305445306
#                 ],
#                 [
#                     "A=6.1",
#                     0.6079137332742048
#                 ],
#                 [
#                     "A=6.15",
#                     0.22281644482798435
#                 ],
#                 [
#                     "A=6.2",
#                     0.9238280927214275
#                 ],
#                 [
#                     "A=6.25",
#                     0.11716130540425995
#                 ],
#                 [
#                     "A=6.3",
#                     0.5267657132011184
#                 ],
#                 [
#                     "A=6.35",
#                     0.6181618553581629
#                 ],
#                 [
#                     "A=6.4",
#                     0.9123983532624496
#                 ],
#                 [
#                     "A=6.45",
#                     0.043758820694327905
#                 ],
#                 [
#                     "A=6.5",
#                     0.6469836928201537
#                 ],
#                 [
#                     "A=6.55",
#                     0.6475904998202295
#                 ],
#                 [
#                     "A=6.6",
#                     0.1462340918178343
#                 ],
#                 [
#                     "A=6.65",
#                     0.7047222968271116
#                 ],
#                 [
#                     "A=6.7",
#                     0.6056163819930477
#                 ],
#                 [
#                     "A=6.75",
#                     0.6064136672791319
#                 ],
#                 [
#                     "A=6.8",
#                     0.15328106441343414
#                 ],
#                 [
#                     "A=6.85",
#                     0.22978239563153158
#                 ],
#                 [
#                     "A=6.9",
#                     0.6784733219803035
#                 ],
#                 [
#                     "A=6.95",
#                     0.6826954037267673
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0.2,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6617385
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "weibull_distribution when A="
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": true
#             },
#             "inverse": false,
#             "boundaryGap": false,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
